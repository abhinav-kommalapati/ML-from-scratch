# %% [markdown]
# Imbalanced Dataset:
#
# A dataset with unequal class distribution

# %%
import numpy as np
import pandas as pd

# %%
#loading the datset

credit_card_data = pd.read_csv('/content/credit_data.csv')

# %%
credit_card_data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0     0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2     1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3     1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4     2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
credit_card_data.tail()
# Out:
#          Time        V1        V2        V3        V4        V5        V6  \
# 150627  93789 -0.487808  0.524641 -1.976990  0.215200  1.706376 -2.220200
# 150628  93790 -4.948835  4.463739 -4.315625 -0.876520 -2.068503 -0.587427
# 150629  93798  1.963076  0.761481 -0.695665  3.900855  0.564233 -0.388571
# 150630  93798  0.000511  1.064202 -0.403154 -0.629699  1.218252 -0.233102
# 150631  93798 -0.796099  0.855510 -1.547924  0.276334  0.257263 -1.366656
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 150627  1.011071 -0.252453  0.716540  ...  0.488790  1.615337 -0.031607
# 150628 -2.512790  3.852223  1.211863  ... -0.302062 -1.216998  0.431651
# 150629  0.243059 -0.305132  0.169108  ...  0.067740  0.454708  0.056026
# 150630  0.870353 -0.143075  1.567454  ... -0.569978 -1.103569  0.041873
# 150631  0.124734       NaN       NaN  ...       NaN       NaN       NaN
#
#              V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
credit_card_data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
#distribution of the 2 classes
credit_card_data['Class'].value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %% [markdown]
# This is highly inbalanced dataset
#
# 0 --> Legit Transaction
# 1 --> Fraud Transactiopn

# %%
legit = credit_card_data[credit_card_data.Class == 0]
fraud = credit_card_data[credit_card_data.Class == 1]

# %%
print(legit.shape)
print(fraud.shape)
# Out:
# (284315, 31)
# (492, 31)

# %% [markdown]
# under-sampling

# %% [markdown]
# Build a sample dataset containg similar  distribution of legit & fraud transaction
#
#
# number of fraud transaction -> 492

# %%
legit_sample = legit.sample(n=492)

# %%
print(legit_sample.shape)
# Out:
# (492, 31)

# %% [markdown]
# Concatenate the Two DataFrames

# %%
new_dataset = pd.concat([legit_sample, fraud], axis = 0)

# %%
new_dataset.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 63488    50738.0  0.134230 -1.563840 -0.466219  1.543372 -0.528855  0.057617
# 159144  112270.0  2.152228 -1.116532 -1.109672 -2.051053 -0.425760  0.291721
# 107615   70524.0 -0.519577  0.787975  1.016971 -1.447062 -0.026693 -0.659907
# 114519   73519.0 -1.087629 -0.032126  2.195686 -0.075740  0.008419 -1.440148
# 212601  138922.0 -0.735051  1.659519 -1.515215 -0.438402  0.589344 -1.058671
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 63488   0.742868 -0.135197  0.061989  ...  0.398943 -0.081707 -0.630585
# 159144 -0.848735  0.041381  0.401207  ... -0.758583 -1.511278  0.416327
# 107615  0.415854  0.093532  0.544053  ... -0.207603 -0.539348 -0.109479
# 114519  0.196441  0.019908 -0.143760  ...  0.086225 -0.121987  0.259947
# 212601  0.803414  0.497688 -0.857933  ...  0.379117  1.110346 -0.200040
#
# ...

# %%
new_dataset.tail()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 279863 -0.882850  0.697211 -2.064945  ...  0.778584 -0.319189  0.639419
# 280143 -1.413170  0.248525 -1.127396  ...  0.370612  0.028234 -0.145640
# 280149 -2.234739  1.210158 -0.652250  ...  0.751826  0.834108  0.190944
# 281144 -2.208002  1.058733 -1.632333  ...  0.583276 -0.269209 -0.456108
# 281674  0.223050 -0.068384  0.577829  ... -0.164350 -0.295135 -0.072173
#
# ...

# %%
new_dataset['Class'].value_counts()
# Out:
# Class
# 0    492
# 1    492
# Name: count, dtype: int64

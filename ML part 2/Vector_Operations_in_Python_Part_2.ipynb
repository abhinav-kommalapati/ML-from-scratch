# %%
import numpy as np

# %% [markdown]
# Dot product of 2 vectors

# %%
a = np.array([2, 3])

b = np.array([4, 4])
a_dot_b = np.dot(a,b)
print(a_dot_b)
# Out:
# 20

# %% [markdown]
# Cross product of 2 vectors

# %%
a = np.array([2, 3])

b = np.array([4, 4])

a_cross_b = np.cross(a, b)


print(a_cross_b)
# Out:
# -4
# <ipython-input-5-d56cbe28e8e9>:5: DeprecationWarning: Arrays of 2-dimensional vectors are deprecated. Use arrays of 3-dimensional vectors instead. (deprecated in NumPy 2.0)
#   a_cross_b = np.cross(a, b)

# %% [markdown]
# Projection of 'a' vector on 'v' vector

# %%
a = np.array([2, 5])

v = np.array([8, -6])

# magnitude of "v" vector
magnitude_of_v = np.sqrt(sum(v**2))

proj_of_a_on_v = (np.dot(a,v)/magnitude_of_v**2)*v

print('Projection of a vector on v vector = ', proj_of_a_on_v)
# Out:
# Projection of a vector on v vector =  [-1.12  0.84]
